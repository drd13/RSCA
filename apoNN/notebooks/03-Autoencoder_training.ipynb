# %%
# %load_ext autoreload

# %autoreload 2

import apogee.tools.read as apread
import matplotlib.pyplot as plt
import apogee.tools.path as apogee_path
from apogee.tools import bitmask

import random
import numpy as np

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import torch.nn as nn

from apoNN.src.datasets import ApogeeDataset

from tagging.src.networks import ConditioningAutoencoder,Embedding_Decoder,Feedforward,ParallelDecoder,Autoencoder

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
apogee_path.change_dr(16)

# %%
allStar= apread.allStar(rmcommissioning=True,main=False,ak=True, akvers='targ',adddist=False)
# Out:
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/apogee/tools/read.py:303: RuntimeWarning: Extinction-corrected J,H,K not added because esutil is not installed
#   warnings.warn("Extinction-corrected J,H,K not added because esutil is not installed",RuntimeWarning)

# %%
upper_temp_cut = allStar["Teff"]<5000
lower_temp_cut = allStar["Teff"]>4000
lower_g_cut = allStar["logg"]>1.5
upper_g_cut = allStar["logg"]<3
snr_cut = allStar["SNR"]>100
snr_highcut = allStar["SNR"]<500
feh_outliercut = allStar["Fe_H"]>-5
o_outliercut = allStar["O_FE"]>-5
c_outliercut = allStar["C_FE"]>-5
na_outliercut = allStar["Na_FE"]>-5
mg_outliercut = allStar["Mg_FE"]>-5
si_outliercut = allStar["Si_FE"]>-5



combined_cut = lower_g_cut & upper_g_cut & lower_temp_cut & upper_temp_cut & snr_cut & snr_highcut & feh_outliercut & o_outliercut &  c_outliercut & na_outliercut & mg_outliercut & si_outliercut

# %%
cut_allStar = allStar[combined_cut]

# %% [markdown]
# ### Parameters

# %%
n_batch = 64
n_z = 20
n_bins = 8575
lr = 0.0001
n_datapoints = 5000

# %% [markdown]
# ### Training

# %%
dataset = ApogeeDataset(cut_allStar[:n_datapoints])
loader = torch.utils.data.DataLoader(dataset = dataset,
                                     batch_size = n_batch,
                                     shuffle= False,
                                     drop_last=True)

# %%
encoder = Feedforward([n_bins,2048,512,128,n_z],activation=nn.LeakyReLU()).to(device)
decoder = Feedforward([n_z,128,512,2048,4096,n_bins],activation=nn.LeakyReLU()).to(device)

autoencoder = Autoencoder(encoder,decoder,n_bins=n_bins).to(device)
optimizer_autoencoder = torch.optim.Adam(autoencoder.parameters(), lr=lr)

# %%
#autoencoder = torch.load("/share/splinter/ddm/taggingProject/apogeeFactory/outputs/pretrained/ae1")
optimizer_autoencoder = torch.optim.Adam(autoencoder.parameters(), lr=lr)

# %%
loss = nn.L1Loss()

# %%
for i in range(20000):
    for j,(x,u,idx) in enumerate(loader):

        optimizer_autoencoder.zero_grad()
        x_pred,z = autoencoder(x.to(device))

        err_pred = loss(x_pred,x.to(device))

        err_tot = err_pred
        err_tot.backward()
        optimizer_autoencoder.step()
        if j%100==0:
            print(f"err:{err_tot},err_pred:{err_pred}")
# Out:
# err:0.8643982410430908,err_pred:0.8643982410430908
# err:0.031680405139923096,err_pred:0.031680405139923096
# err:0.031029753386974335,err_pred:0.031029753386974335
# err:0.03191349282860756,err_pred:0.03191349282860756
# err:0.03336818516254425,err_pred:0.03336818516254425
# err:0.0355432853102684,err_pred:0.0355432853102684
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _try_while_unread_hdus(self, func, *args, **kwargs)
#    1110             try:
# -> 1111                 return func(*args, **kwargs)
#    1112             except Exception:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-3481f6ef61ba> in <module>
#       1 for i in range(20000):
# ----> 2     for j,(x,u,idx) in enumerate(loader):
#       3
#       4         optimizer_autoencoder.zero_grad()
#       5         x_pred,z = autoencoder(x.to(device))
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /share/splinter/ddm/taggingProject/apogeeFactory/apoNN/src/datasets.py in __getitem__(self, idx)
#      81
#      82             if item == "aspcap":
# ---> 83                 spec,hed = self.get_pseudonormalized(apogee_id,loc,telescope)
#      84                 returned.append(torch.tensor(spec.astype(np.float32)))
#      85
#
# /share/splinter/ddm/taggingProject/apogeeFactory/apoNN/src/datasets.py in get_pseudonormalized(self, apogee_id, loc, telescope)
#      45
#      46     def get_pseudonormalized(self,apogee_id,loc,telescope):
# ---> 47         return apread.aspcapStar(loc_id=str(loc),apogee_id=apogee_id,telescope=telescope,ext=1)
#      48
#      49     def get_apstar(self,apogee_id,loc,telescope):
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/apogee/tools/read.py in output_wrapper(*args, **kwargs)
#      79     @wraps(func)
#      80     def output_wrapper(*args,**kwargs):
# ---> 81         out= func(*args,**kwargs)
#      82         if kwargs.get('header',True):
#      83             out, hdr= out
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/apogee/tools/read.py in aspcapStar(loc_id, apogee_id, telescope, ext, dr, header, aspcapWavegrid)
#     948         # Using astropy, need to read header separately
#     949         if header:
# --> 950             data= fitsread(filePath,ext), headerread(filePath,ext)
#     951         else:
#     952             data= fitsread(filePath,ext)
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/convenience.py in getheader(filename, *args, **kwargs)
#     105     hdulist, extidx = _getext(filename, mode, *args, **kwargs)
#     106     try:
# --> 107         hdu = hdulist[extidx]
#     108         header = hdu.header
#     109     finally:
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     312         try:
#     313             return self._try_while_unread_hdus(super().__getitem__,
# --> 314                                                self._positive_index_of(key))
#     315         except IndexError as e:
#     316             # Raise a more helpful IndexError if the file was not fully read.
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _try_while_unread_hdus(self, func, *args, **kwargs)
#    1111                 return func(*args, **kwargs)
#    1112             except Exception:
# -> 1113                 if self._read_next_hdu():
#    1114                     continue
#    1115                 else:
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/hdulist.py in _read_next_hdu(self)
#    1152                                 fileobj.seek(offset, os.SEEK_SET)
#    1153
# -> 1154                         hdu = _BaseHDU.readfrom(fileobj, **kwargs)
#    1155                     except EOFError:
#    1156                         self._read_all = True
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/base.py in readfrom(cls, fileobj, checksum, ignore_missing_end, **kwargs)
#     325         hdu = cls._readfrom_internal(fileobj, checksum=checksum,
#     326                                      ignore_missing_end=ignore_missing_end,
# --> 327                                      **kwargs)
#     328
#     329         # If the checksum had to be checked the data may have already been read
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/base.py in _readfrom_internal(cls, data, header, checksum, ignore_missing_end, **kwargs)
#     485
#     486         # data area size, including padding
# --> 487         size = hdu.size
#     488         hdu._data_size = size + _pad_length(size)
#     489
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/hdu/base.py in size(self)
#     957             size = 1
#     958             for idx in range(naxis):
# --> 959                 size = size * self._header['NAXIS' + str(idx + 1)]
#     960             bitpix = self._header['BITPIX']
#     961             gcount = self._header.get('GCOUNT', 1)
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/header.py in __getitem__(self, key)
#    2048
#    2049         try:
# -> 2050             return self._cards[key].value
#    2051         except KeyError:
#    2052             # parse the Card and store it
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/io/fits/card.py in value(self)
#     290                 self._value = value = UNDEFINED
#     291
# --> 292         if conf.strip_header_whitespace and isinstance(value, str):
#     293             value = value.rstrip()
#     294
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/config/configuration.py in __get__(self, obj, objtype)
#     276         if obj is None:
#     277             return self
# --> 278         return self()
#     279
#     280     def set(self, value):
#
# /share/splinter/ddm/taggenv/lib64/python3.6/site-packages/astropy/config/configuration.py in __call__(self)
#     400         options = []
#     401         sec = get_config(self.module, rootname=self.rootname)
# --> 402         if self.name in sec:
#     403             options.append((sec[self.name], self.module, self.name))
#     404
#
# KeyboardInterrupt:

# %%
print(i)

# %%
torch.min(x)

# %%
autoencoder = torch.load("/share/splinter/ddm/taggingProject/apogeeFactory/outputs/nn/ae/ae_apstar_l1/ae_700.p")
#autoencoder = torch.load("/share/splinter/ddm/taggingProject/apogeeFactory/outputs/nn/random/ae1")

# %% [markdown]
# ## Latent Visualization

# %%
def get_z(idx,dataset):
    _,z = autoencoder(dataset[idx][0].to(device).unsqueeze(0))
    return z

# %%
def get_v(idx,dataset,feedforward):
    _,z = autoencoder(dataset[idx][0].to(device).unsqueeze(0))
    v = feedforward(z)
    return v

# %%
n_datapoints = 5000
z_array = np.array([get_z(i,dataset).detach().cpu().numpy() for i in range(n_datapoints)]).squeeze()
z_calibrated = (z_array- np.mean(z_array,axis=0)).T

# %%
z_calibrated.shape
# Out:
# (20, 5000)

# %%
abundances_array = np.array([cut_allStar["Teff"],cut_allStar["logg"],cut_allStar["Fe_H"],cut_allStar["O_FE"],cut_allStar["C_FE"],cut_allStar["Na_FE"],cut_allStar["Mg_FE"],cut_allStar["Si_FE"]])[:,:n_datapoints].T
abundances_array = (abundances_array-np.min(abundances_array,axis=0))/(np.max(abundances_array,axis=0)-np.min(abundances_array,axis=0)).T
abundances_calibrated = (abundances_array-np.mean(abundances_array,axis=0)).T

# %%
W_est =np.dot(abundances_calibrated,np.linalg.pinv(z_calibrated))

# %%
abundances_calibrated_est = np.dot(W_est,z_calibrated)

# %%
idx = 2
plt.scatter(abundances_calibrated[idx],abundances_calibrated_est[idx],s=5,alpha=0.5)
plt.plot([-1,1],[-1,1],c="red")
plt.title("2900")
plt.ylim(-0.8,0.6)
# Out:
# (-0.8, 0.6)

# %%
idx = 1
plt.scatter(abundances_calibrated[idx],abundances_calibrated_est[idx],s=5,alpha=0.5)
plt.plot([-1,1],[-1,1],c="red")
plt.title("2900")
plt.ylim(-0.8,0.6)
# Out:
# (-0.8, 0.6)

# %%
plt.scatter(abundances_calibrated_est[0],abundances_calibrated_est[1],s=5,c=abundances_calibrated[2][:5000])

# %%
plt.scatter(abundances_calibrated[0],abundances_calibrated[1],s=5,c=abundances_calibrated_est[2][:5000])

# %%
plt.scatter(abundances_calibrated[0],abundances_calibrated[1],s=5,c=abundances_calibrated[2][:5000])

# %%
plt.scatter(abundances_calibrated[2][:5000],abundances_calibrated[1][:5000],s=5,c=abundances_calibrated[2][:5000])

# %%
plt.scatter(abundances_calibrated_est[2][:5000],abundances_calibrated_est[1][:5000],s=5,c=abundances_calibrated_est[2][:5000])

# %%
plt.scatter(abundances_calibrated_est[2][:5000],abundances_calibrated_est[0][:5000],s=5,c=abundances_calibrated_est[3][:5000])

# %%
plt.scatter(abundances_calibrated[2][:5000],abundances_calibrated[0][:5000],s=5,c=abundances_calibrated[3][:5000])

# %%
idx = 7
plt.scatter(abundances_calibrated[idx],abundances_calibrated_est[idx],s=5,alpha=0.5)
plt.plot([-1,1],[-1,1],c="red")
plt.title("2900")
plt.ylim(-0.8,0.6)

# %%
abundances_calibrated[0].shape

# %%
plt.hist(abundances_calibrated[4],bins=100)

# %%
plt.scatter(abundances_calibrated[0],abundances_calibrated_est[0],s=5,alpha=0.5)
plt.title("2900")
plt.ylim(-0.8,0.6)

# %%
plt.scatter(abundances_calibrated[0],abundances_calibrated_est[0],s=5,alpha=0.5)
plt.title("2900")
plt.ylim(-0.8,0.6)

# %%
plt.scatter(abundances_calibrated[0][0:500],abundances_calibrated[1][0:500],s=5,alpha=0.5)

# %%
plt.scatter(abundances_calibrated_est[0][0:1000],abundances_calibrated_est[1][0:1000],s=5,alpha=0.5)

# %% [markdown]
# ## Non-linear better
#
# ### Setup

# %%
autoencoder

# %%
feedforward = Feedforward([40,256,128,1],activation=nn.SELU()).to(device)
loss = torch.nn.MSELoss()
optimizer = torch.optim.Adam(feedforward.parameters(),lr=0.0001)

# %%
truth_tensor = torch.tensor(abundances_calibrated[7]).to(device)

# %%
feedforwards = []
for idx_estimated in range(len(abundances_calibrated)):
    truth_tensor = torch.tensor(abundances_calibrated[idx_estimated]).to(device)
    
    feedforward = Feedforward([40,512,256,128,1],activation=nn.SELU()).to(device)
    loss = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(feedforward.parameters(),lr=0.0001)

    for i in range(5):
        for j,(x,u,idx) in enumerate(loader):
            optimizer.zero_grad()
            x_pred,z = autoencoder(x.to(device))
            pred = feedforward(z.detach())
            true = truth_tensor[idx]

            err = loss(pred,true.unsqueeze(1))    
            err.backward()
            optimizer.step()
            if j%100==0:
                print(f"epoch:{i},err:{err}")
                
    feedforwards.append(feedforward)

# %%
abundances_non_linear = []
for feedforward in feedforwards:
    ab = np.array([get_v(i,dataset,feedforward).detach().cpu().numpy() for i in range(n_datapoints)]).squeeze()
    abundances_non_linear.append(ab)

# %%
nonlinear_array = np.array([get_v(i,dataset).detach().cpu().numpy() for i in range(n_datapoints)]).squeeze()

# %%
plt.scatter(abundances_calibrated[0],nonlinear_array,s=5,alpha=0.5)
plt.title("2900")
plt.ylim(-0.8,0.6)
plt.xlim(-0.8,0.6)

# %%
idx = 5
plt.scatter(abundances_calibrated[idx],abundances_non_linear[idx],s=5,alpha=0.5)
plt.plot([-1,1],[-1,1],c="red")

plt.title("2900")
plt.ylim(-0.8,0.6)
plt.xlim(-0.8,0.6)
